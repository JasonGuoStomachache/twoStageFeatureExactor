# %%
# -*- coding: utf-8 -*-
"""
YOLO标注文件+图片+描述文件批量处理工具
功能：
1. 按规则修改YOLO标注文件类别编号
2. 同步修改标注文件、图片文件、描述文件的文件名（更新类别编码）
3. 修改描述文件（JSON格式）内部的Image filename字段
4. 自动复制处理后的文件到输出目录（不覆盖原文件）
"""

# 导入必要模块
import os
import shutil
import re
import json

# ===================== 配置参数（请根据实际情况修改）=====================
# 原文件路径
ANNOTATIONS_INPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data\bbox\08_wheat_midge"  # 原标注文件目录
IMAGES_INPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge"    # 原图片文件目录
CAPTION_CN_INPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data\caption\08_wheat_midge"           # 中文描述文件目录
CAPTION_EN_INPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data\caption_en\08_wheat_midge"        # 英文描述文件目录

# 输出文件路径（自动创建，避免覆盖原文件）
ANNOTATIONS_OUTPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data_processed\bbox_processed\07_wheat_midge"
IMAGES_OUTPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data_processed\images_processed\07_wheat_midge"
CAPTION_CN_OUTPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data_processed\caption_processed\07_wheat_midge"
CAPTION_EN_OUTPUT_DIR = r"D:\25.10.29backup\25.7.24\pest_text\api\data_processed\caption_en_processed\07_wheat_midge"

# 类别映射规则（key=原类别，value=新类别）
CLASS_MAPPING = {
    1: 3,
    2: 0,
    3: 2,
    4: 1,
    5: 4,
    6: 5,
    7: 6,
    8: 7
}

# 文件名配置（根据你的文件名格式调整）
FILE_PREFIX = "PD16-MW-"               # 文件名前缀
NUM_DIGITS_TOTAL = 8                   # 文件名中数字部分总位数
CLASS_CODE_DIGITS = 3                  # 数字部分中类别编码的位数（前N位）
# 文件后缀配置
IMAGE_SUFFIX = ".jpg"                  # 图片文件后缀（原文件）
ANNOTATION_SUFFIX = ".txt"             # 标注文件后缀
CAPTION_CN_SUFFIX = "_caption.txt"     # 中文描述文件后缀
CAPTION_EN_SUFFIX = "_caption_en.txt"  # 英文描述文件后缀
IMAGE_JSON_SUFFIX = ".jpg"             # JSON中Image filename的后缀（示例中是.jpg）
# ========================================================================

# 创建输出目录（如果不存在）
def create_output_dirs():
    """创建所有输出目录"""
    dirs = [
        ANNOTATIONS_OUTPUT_DIR,
        IMAGES_OUTPUT_DIR,
        CAPTION_CN_OUTPUT_DIR,
        CAPTION_EN_OUTPUT_DIR
    ]
    for dir_path in dirs:
        os.makedirs(dir_path, exist_ok=True)
    
    print(f"输出目录已创建/确认：")
    for dir_path in dirs:
        print(f"- {dir_path}")

# 解析基础文件名（提取类别编码和序号，支持所有文件类型）
def parse_base_filename(filename):
    """
    从任意类型文件中提取基础信息
    支持的文件名格式：
    - 标注文件：PD16-MW-XXXXXXXX.txt
    - 图片文件：PD16-MW-XXXXXXXX.png
    - 中文描述：PD16-MW-XXXXXXXX_caption.txt
    - 英文描述：PD16-MW-XXXXXXXX_caption_en.txt
    输出：(原类别编码int, 序号str, 文件类型标识str)
    文件类型标识：annotation/image/caption_cn/caption_en
    """
    # 定义所有支持的文件名模式
    patterns = [
        # (正则表达式, 文件类型标识)
        (rf"^{FILE_PREFIX}(\d{{{NUM_DIGITS_TOTAL}}}){ANNOTATION_SUFFIX}$", "annotation"),
        (rf"^{FILE_PREFIX}(\d{{{NUM_DIGITS_TOTAL}}}){IMAGE_SUFFIX}$", "image"),
        (rf"^{FILE_PREFIX}(\d{{{NUM_DIGITS_TOTAL}}}){CAPTION_CN_SUFFIX}$", "caption_cn"),
        (rf"^{FILE_PREFIX}(\d{{{NUM_DIGITS_TOTAL}}}){CAPTION_EN_SUFFIX}$", "caption_en")
    ]
    
    for pattern, file_type in patterns:
        match = re.match(pattern, filename)
        if match:
            num_str = match.group(1)  # 8位数字部分（如00200001）
            # 提取类别编码（前CLASS_CODE_DIGITS位）和序号（后几位）
            class_code_str = num_str[:CLASS_CODE_DIGITS]
            sequence_str = num_str[CLASS_CODE_DIGITS:]
            
            try:
                original_class_code = int(class_code_str)
            except ValueError:
                raise ValueError(f"文件名中的类别编码不是数字：{class_code_str}（文件名：{filename}）")
            
            return original_class_code, sequence_str, file_type
    
    # 未匹配到任何支持的格式
    raise ValueError(f"文件名格式不支持：{filename}")

# 生成新的文件名（根据基础信息和文件类型）
def generate_new_filename(original_class_code, sequence_str, file_type):
    """根据原类别编码、序号和文件类型生成新文件名"""
    # 获取映射后的新类别
    if original_class_code not in CLASS_MAPPING:
        raise KeyError(f"原类别 {original_class_code} 没有对应的映射规则，请检查CLASS_MAPPING配置")
    
    new_class_code = CLASS_MAPPING[original_class_code]
    # 生成新的数字部分（类别编码补零到指定位数 + 序号）
    new_class_code_str = f"{new_class_code:0{CLASS_CODE_DIGITS}d}"
    new_num_str = new_class_code_str + sequence_str
    
    # 根据文件类型生成对应文件名
    if file_type == "annotation":
        return f"{FILE_PREFIX}{new_num_str}{ANNOTATION_SUFFIX}"
    elif file_type == "image":
        return f"{FILE_PREFIX}{new_num_str}{IMAGE_SUFFIX}"
    elif file_type == "caption_cn":
        return f"{FILE_PREFIX}{new_num_str}{CAPTION_CN_SUFFIX}"
    elif file_type == "caption_en":
        return f"{FILE_PREFIX}{new_num_str}{CAPTION_EN_SUFFIX}"
    else:
        raise ValueError(f"不支持的文件类型：{file_type}")

# 生成JSON中Image filename的新值
def generate_new_image_json_filename(original_class_code, sequence_str):
    """生成修改后的Image filename字段值（如PD16-MW-00000001.jpg）"""
    new_class_code = CLASS_MAPPING[original_class_code]
    new_class_code_str = f"{new_class_code:0{CLASS_CODE_DIGITS}d}"
    new_num_str = new_class_code_str + sequence_str
    return f"{FILE_PREFIX}{new_num_str}{IMAGE_JSON_SUFFIX}"

# 处理单个标注文件
def process_annotation_file(annotation_path, new_annotation_path):
    """读取原标注文件，修改类别编号，写入新文件"""
    modified_lines = []
    with open(annotation_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    for line_idx, line in enumerate(lines, 1):
        line = line.strip()
        if not line:  # 跳过空行
            modified_lines.append("")
            continue
        
        # YOLO标注格式：class_id x_center y_center width height
        parts = line.split()
        if len(parts) != 5:
            print(f"警告：标注文件 {os.path.basename(annotation_path)} 第{line_idx}行格式错误，跳过该行：{line}")
            continue
        
        # 解析原类别ID
        try:
            original_class_id = int(parts[0])
        except ValueError:
            print(f"警告：标注文件 {os.path.basename(annotation_path)} 第{line_idx}行类别ID不是数字，跳过该行：{line}")
            continue
        
        # 映射到新类别ID
        if original_class_id in CLASS_MAPPING:
            new_class_id = CLASS_MAPPING[original_class_id]
            new_line = f"{new_class_id} {' '.join(parts[1:])}"
            modified_lines.append(new_line)
        else:
            modified_lines.append(line)
            print(f"警告：标注文件 {os.path.basename(annotation_path)} 第{line_idx}行出现未配置的类别ID {original_class_id}，保留原类别")
    
    # 写入新标注文件
    with open(new_annotation_path, 'w', encoding='utf-8') as f:
        f.write('\n'.join(modified_lines))
    
    return len(modified_lines) - modified_lines.count("")  # 返回有效标注行数

# 处理单个描述文件（JSON格式）
def process_caption_file(caption_path, new_caption_path, original_class_code, sequence_str):
    """
    处理描述文件：
    1. 读取JSON内容
    2. 修改Image filename字段
    3. 保存到新文件
    """
    try:
        # 读取JSON文件（支持中文编码）
        with open(caption_path, 'r', encoding='utf-8') as f:
            try:
                json_data = json.load(f)
            except json.JSONDecodeError as e:
                raise ValueError(f"JSON格式错误：{str(e)}")
        
        # 检查并修改Image filename字段
        if "Image filename" in json_data :
            original_image_filename = json_data["Image filename"]
            new_image_filename = generate_new_image_json_filename(original_class_code, sequence_str)
            json_data["Image filename"] = new_image_filename
            print(f"📝 Image filename修改：{original_image_filename} → {new_image_filename}")
            
        elif "图片的文件名" in json_data:
            original_image_filename = json_data["图片的文件名"]
            new_image_filename = generate_new_image_json_filename(original_class_code, sequence_str)
            json_data["图片的文件名"] = new_image_filename
            print(f"📝 图片的文件名修改：{original_image_filename} → {new_image_filename}")
        else:
            print(f"警告：描述文件 {os.path.basename(caption_path)} 缺少Image filename字段，跳过该字段修改")
            
        
        # 写入修改后的JSON文件（保持缩进格式）
        with open(new_caption_path, 'w', encoding='utf-8') as f:
            json.dump(json_data, f, ensure_ascii=False, indent=4)
        
        return True
    
    except Exception as e:
        raise Exception(f"JSON处理失败：{str(e)}")

# 处理单个文件对（标注+图片，可选关联描述文件）
def process_annotation_image_pair(annotation_filename):
    """处理标注文件和对应的图片文件"""
    annotation_basename = annotation_filename
    annotation_path = os.path.join(ANNOTATIONS_INPUT_DIR, annotation_basename)
    
    try:
        # 解析原文件名
        original_class_code, sequence_str, _ = parse_base_filename(annotation_basename)
        
        # 1. 处理标注文件
        new_annotation_basename = generate_new_filename(original_class_code, sequence_str, "annotation")
        new_annotation_path = os.path.join(ANNOTATIONS_OUTPUT_DIR, new_annotation_basename)
        valid_lines = process_annotation_file(annotation_path, new_annotation_path)
        print(f"✅ 标注文件：{annotation_basename} → {new_annotation_basename}（有效行：{valid_lines}）")
        
        # 2. 处理图片文件
        image_basename = annotation_filename.replace(ANNOTATION_SUFFIX, IMAGE_SUFFIX)
        print(image_basename)
        image_path = os.path.join(IMAGES_INPUT_DIR, image_basename)
        if os.path.exists(image_path):
            new_image_basename = generate_new_filename(original_class_code, sequence_str, "image")
            new_image_path = os.path.join(IMAGES_OUTPUT_DIR, new_image_basename)
            shutil.copy2(image_path, new_image_path)
            print(f"✅ 图片文件：{image_basename} → {new_image_basename}")
        else:
            print(f"⚠️  图片文件不存在：{image_path}，跳过")
        
        return True
    
    except Exception as e:
        print(f"❌ 处理失败 {annotation_basename}：{str(e)}")
        return False

# 批量处理描述文件（中文/英文）
def process_all_caption_files():
    """批量处理中文和英文描述文件"""
    print("\n" + "="*50)
    print("开始处理描述文件...")
    print("="*50)
    
    # 定义需要处理的描述文件目录和类型
    caption_configs = [
        (CAPTION_CN_INPUT_DIR, CAPTION_CN_OUTPUT_DIR, "caption_cn", "中文"),
        (CAPTION_EN_INPUT_DIR, CAPTION_EN_OUTPUT_DIR, "caption_en", "英文")
    ]
    
    total_success = 0
    total_fail = 0
    
    for input_dir, output_dir, file_type, lang_name in caption_configs:
        print(f"\n【{lang_name}描述文件】")
        print(f"处理目录：{input_dir}")
        
        # 筛选符合条件的文件（以对应的caption后缀结尾）
        suffix = CAPTION_CN_SUFFIX if file_type == "caption_cn" else CAPTION_EN_SUFFIX
        caption_filenames = [f for f in os.listdir(input_dir) if f.endswith(suffix)]
        
        if not caption_filenames:
            print(f"⚠️  未找到符合条件的{lang_name}描述文件（需以{suffix}结尾）")
            continue
        
        print(f"找到 {len(caption_filenames)} 个{lang_name}描述文件，开始处理...")
        
        success_count = 0
        fail_count = 0
        
        for filename in caption_filenames:
            try:
                # 解析文件名
                original_class_code, sequence_str, parsed_type = parse_base_filename(filename)
                if parsed_type != file_type:
                    print(f"⚠️  文件名格式不匹配{lang_name}描述文件：{filename}，跳过")
                    continue
                
                # 生成新文件名
                new_filename = generate_new_filename(original_class_code, sequence_str, file_type)
                input_path = os.path.join(input_dir, filename)
                output_path = os.path.join(output_dir, new_filename)
                
                # 处理文件内容并保存
                if process_caption_file(input_path, output_path, original_class_code, sequence_str):
                    print(f"✅ {filename} → {new_filename}")
                    success_count += 1
                else:
                    fail_count += 1
            
            except Exception as e:
                print(f"❌ 处理失败 {filename}：{str(e)}")
                fail_count += 1
        
        # 统计当前语言的处理结果
        print(f"{lang_name}描述文件处理完成：成功{success_count}个，失败{fail_count}个")
        total_success += success_count
        total_fail += fail_count
    
    return total_success, total_fail

# 主处理函数
def main():
    print("="*60)
    print("YOLO标注+图片+描述文件批量处理工具")
    print("="*60)
    
    # 1. 创建输出目录
    create_output_dirs()
    
    # 2. 处理标注文件和图片文件
    print("\n" + "="*50)
    print("开始处理标注文件和图片文件...")
    print("="*50)
    
    # 获取所有符合条件的标注文件
    annotation_filenames = [f for f in os.listdir(ANNOTATIONS_INPUT_DIR) 
                           if f.endswith(ANNOTATION_SUFFIX) and re.match(rf"^{FILE_PREFIX}\d{{{NUM_DIGITS_TOTAL}}}{ANNOTATION_SUFFIX}$", f)]
    
    if not annotation_filenames:
        print(f"⚠️  在标注目录 {ANNOTATIONS_INPUT_DIR} 中未找到符合格式的标注文件")
    else:
        print(f"找到 {len(annotation_filenames)} 个标注文件，开始处理...\n")
        
        ann_success = 0
        ann_fail = 0
        
        for idx, filename in enumerate(annotation_filenames, 1):
            print(f"\n【{idx}/{len(annotation_filenames)}】")
            if process_annotation_image_pair(filename):
                ann_success += 1
            else:
                ann_fail += 1
        
        print(f"\n标注+图片处理统计：成功{ann_success}个，失败{ann_fail}个")
    
    # 3. 处理描述文件
    cap_success, cap_fail = process_all_caption_files()
    
    # 4. 输出总体处理结果
    print("\n" + "="*60)
    print("全部处理完成！")
    print("="*60)
    print(f"标注+图片文件：成功{ann_success if 'ann_success' in locals() else 0}个，失败{ann_fail if 'ann_fail' in locals() else 0}个")
    print(f"描述文件：成功{cap_success}个，失败{cap_fail}个")
    print(f"\n处理后的文件保存位置：")
    print(f"- 标注文件：{ANNOTATIONS_OUTPUT_DIR}")
    print(f"- 图片文件：{IMAGES_OUTPUT_DIR}")
    print(f"- 中文描述：{CAPTION_CN_OUTPUT_DIR}")
    print(f"- 英文描述：{CAPTION_EN_OUTPUT_DIR}")
    print("="*60)

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# ============================================================
# YOLO标注+图片+描述文件批量处理工具
# ============================================================
# 输出目录已创建/确认：
# - D:\25.10.29backup\25.7.24\pest_text\api\data_processed\bbox_processed\07_wheat_midge
# - D:\25.10.29backup\25.7.24\pest_text\api\data_processed\images_processed\07_wheat_midge
# - D:\25.10.29backup\25.7.24\pest_text\api\data_processed\caption_processed\07_wheat_midge
# - D:\25.10.29backup\25.7.24\pest_text\api\data_processed\caption_en_processed\07_wheat_midge
#
# ==================================================
# 开始处理标注文件和图片文件...
# ==================================================
# 找到 136 个标注文件，开始处理...
#
#
# 【1/136】
# ✅ 标注文件：PD16-MW-00800000.txt → PD16-MW-00700000.txt（有效行：1）
# PD16-MW-00800000.jpg
# ✅ 图片文件：PD16-MW-00800000.jpg → PD16-MW-00700000.jpg
#
# 【2/136】
# ✅ 标注文件：PD16-MW-00800001.txt → PD16-MW-00700001.txt（有效行：1）
# PD16-MW-00800001.jpg
# ✅ 图片文件：PD16-MW-00800001.jpg → PD16-MW-00700001.jpg
#
# 【3/136】
# ✅ 标注文件：PD16-MW-00800002.txt → PD16-MW-00700002.txt（有效行：2）
# PD16-MW-00800002.jpg
# ✅ 图片文件：PD16-MW-00800002.jpg → PD16-MW-00700002.jpg
#
# 【4/136】
# ✅ 标注文件：PD16-MW-00800003.txt → PD16-MW-00700003.txt（有效行：3）
# PD16-MW-00800003.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800003.jpg，跳过
#
# 【5/136】
# ✅ 标注文件：PD16-MW-00800004.txt → PD16-MW-00700004.txt（有效行：1）
# PD16-MW-00800004.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800004.jpg，跳过
#
# 【6/136】
# ✅ 标注文件：PD16-MW-00800005.txt → PD16-MW-00700005.txt（有效行：2）
# PD16-MW-00800005.jpg
# ✅ 图片文件：PD16-MW-00800005.jpg → PD16-MW-00700005.jpg
#
# 【7/136】
# ✅ 标注文件：PD16-MW-00800006.txt → PD16-MW-00700006.txt（有效行：1）
# PD16-MW-00800006.jpg
# ✅ 图片文件：PD16-MW-00800006.jpg → PD16-MW-00700006.jpg
#
# 【8/136】
# ✅ 标注文件：PD16-MW-00800007.txt → PD16-MW-00700007.txt（有效行：1）
# PD16-MW-00800007.jpg
# ✅ 图片文件：PD16-MW-00800007.jpg → PD16-MW-00700007.jpg
#
# 【9/136】
# ✅ 标注文件：PD16-MW-00800009.txt → PD16-MW-00700009.txt（有效行：1）
# PD16-MW-00800009.jpg
# ✅ 图片文件：PD16-MW-00800009.jpg → PD16-MW-00700009.jpg
#
# 【10/136】
# ✅ 标注文件：PD16-MW-00800010.txt → PD16-MW-00700010.txt（有效行：10）
# PD16-MW-00800010.jpg
# ✅ 图片文件：PD16-MW-00800010.jpg → PD16-MW-00700010.jpg
#
# 【11/136】
# ✅ 标注文件：PD16-MW-00800011.txt → PD16-MW-00700011.txt（有效行：1）
# PD16-MW-00800011.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800011.jpg，跳过
#
# 【12/136】
# ✅ 标注文件：PD16-MW-00800012.txt → PD16-MW-00700012.txt（有效行：1）
# PD16-MW-00800012.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800012.jpg，跳过
#
# 【13/136】
# ✅ 标注文件：PD16-MW-00800013.txt → PD16-MW-00700013.txt（有效行：2）
# PD16-MW-00800013.jpg
# ✅ 图片文件：PD16-MW-00800013.jpg → PD16-MW-00700013.jpg
#
# 【14/136】
# ✅ 标注文件：PD16-MW-00800014.txt → PD16-MW-00700014.txt（有效行：4）
# PD16-MW-00800014.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800014.jpg，跳过
#
# 【15/136】
# ✅ 标注文件：PD16-MW-00800015.txt → PD16-MW-00700015.txt（有效行：3）
# PD16-MW-00800015.jpg
# ✅ 图片文件：PD16-MW-00800015.jpg → PD16-MW-00700015.jpg
#
# 【16/136】
# ✅ 标注文件：PD16-MW-00800016.txt → PD16-MW-00700016.txt（有效行：1）
# PD16-MW-00800016.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800016.jpg，跳过
#
# 【17/136】
# ✅ 标注文件：PD16-MW-00800017.txt → PD16-MW-00700017.txt（有效行：1）
# PD16-MW-00800017.jpg
# ✅ 图片文件：PD16-MW-00800017.jpg → PD16-MW-00700017.jpg
#
# 【18/136】
# ✅ 标注文件：PD16-MW-00800018.txt → PD16-MW-00700018.txt（有效行：2）
# PD16-MW-00800018.jpg
# ✅ 图片文件：PD16-MW-00800018.jpg → PD16-MW-00700018.jpg
#
# 【19/136】
# ✅ 标注文件：PD16-MW-00800020.txt → PD16-MW-00700020.txt（有效行：4）
# PD16-MW-00800020.jpg
# ✅ 图片文件：PD16-MW-00800020.jpg → PD16-MW-00700020.jpg
#
# 【20/136】
# ✅ 标注文件：PD16-MW-00800021.txt → PD16-MW-00700021.txt（有效行：3）
# PD16-MW-00800021.jpg
# ✅ 图片文件：PD16-MW-00800021.jpg → PD16-MW-00700021.jpg
#
# 【21/136】
# ✅ 标注文件：PD16-MW-00800022.txt → PD16-MW-00700022.txt（有效行：2）
# PD16-MW-00800022.jpg
# ✅ 图片文件：PD16-MW-00800022.jpg → PD16-MW-00700022.jpg
#
# 【22/136】
# ✅ 标注文件：PD16-MW-00800024.txt → PD16-MW-00700024.txt（有效行：1）
# PD16-MW-00800024.jpg
# ✅ 图片文件：PD16-MW-00800024.jpg → PD16-MW-00700024.jpg
#
# 【23/136】
# ✅ 标注文件：PD16-MW-00800025.txt → PD16-MW-00700025.txt（有效行：4）
# PD16-MW-00800025.jpg
# ✅ 图片文件：PD16-MW-00800025.jpg → PD16-MW-00700025.jpg
#
# 【24/136】
# ✅ 标注文件：PD16-MW-00800026.txt → PD16-MW-00700026.txt（有效行：1）
# PD16-MW-00800026.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800026.jpg，跳过
#
# 【25/136】
# ✅ 标注文件：PD16-MW-00800027.txt → PD16-MW-00700027.txt（有效行：4）
# PD16-MW-00800027.jpg
# ✅ 图片文件：PD16-MW-00800027.jpg → PD16-MW-00700027.jpg
#
# 【26/136】
# ✅ 标注文件：PD16-MW-00800029.txt → PD16-MW-00700029.txt（有效行：1）
# PD16-MW-00800029.jpg
# ✅ 图片文件：PD16-MW-00800029.jpg → PD16-MW-00700029.jpg
#
# 【27/136】
# ✅ 标注文件：PD16-MW-00800030.txt → PD16-MW-00700030.txt（有效行：1）
# PD16-MW-00800030.jpg
# ✅ 图片文件：PD16-MW-00800030.jpg → PD16-MW-00700030.jpg
#
# 【28/136】
# ✅ 标注文件：PD16-MW-00800031.txt → PD16-MW-00700031.txt（有效行：1）
# PD16-MW-00800031.jpg
# ✅ 图片文件：PD16-MW-00800031.jpg → PD16-MW-00700031.jpg
#
# 【29/136】
# ✅ 标注文件：PD16-MW-00800032.txt → PD16-MW-00700032.txt（有效行：1）
# PD16-MW-00800032.jpg
# ✅ 图片文件：PD16-MW-00800032.jpg → PD16-MW-00700032.jpg
#
# 【30/136】
# ✅ 标注文件：PD16-MW-00800033.txt → PD16-MW-00700033.txt（有效行：1）
# PD16-MW-00800033.jpg
# ✅ 图片文件：PD16-MW-00800033.jpg → PD16-MW-00700033.jpg
#
# 【31/136】
# ✅ 标注文件：PD16-MW-00800034.txt → PD16-MW-00700034.txt（有效行：1）
# PD16-MW-00800034.jpg
# ✅ 图片文件：PD16-MW-00800034.jpg → PD16-MW-00700034.jpg
#
# 【32/136】
# ✅ 标注文件：PD16-MW-00800035.txt → PD16-MW-00700035.txt（有效行：5）
# PD16-MW-00800035.jpg
# ✅ 图片文件：PD16-MW-00800035.jpg → PD16-MW-00700035.jpg
#
# 【33/136】
# ✅ 标注文件：PD16-MW-00800038.txt → PD16-MW-00700038.txt（有效行：4）
# PD16-MW-00800038.jpg
# ✅ 图片文件：PD16-MW-00800038.jpg → PD16-MW-00700038.jpg
#
# 【34/136】
# ✅ 标注文件：PD16-MW-00800039.txt → PD16-MW-00700039.txt（有效行：1）
# PD16-MW-00800039.jpg
# ✅ 图片文件：PD16-MW-00800039.jpg → PD16-MW-00700039.jpg
#
# 【35/136】
# ✅ 标注文件：PD16-MW-00800040.txt → PD16-MW-00700040.txt（有效行：1）
# PD16-MW-00800040.jpg
# ✅ 图片文件：PD16-MW-00800040.jpg → PD16-MW-00700040.jpg
#
# 【36/136】
# ✅ 标注文件：PD16-MW-00800042.txt → PD16-MW-00700042.txt（有效行：1）
# PD16-MW-00800042.jpg
# ✅ 图片文件：PD16-MW-00800042.jpg → PD16-MW-00700042.jpg
#
# 【37/136】
# ✅ 标注文件：PD16-MW-00800043.txt → PD16-MW-00700043.txt（有效行：1）
# PD16-MW-00800043.jpg
# ✅ 图片文件：PD16-MW-00800043.jpg → PD16-MW-00700043.jpg
#
# 【38/136】
# ✅ 标注文件：PD16-MW-00800044.txt → PD16-MW-00700044.txt（有效行：5）
# PD16-MW-00800044.jpg
# ✅ 图片文件：PD16-MW-00800044.jpg → PD16-MW-00700044.jpg
#
# 【39/136】
# ✅ 标注文件：PD16-MW-00800045.txt → PD16-MW-00700045.txt（有效行：2）
# PD16-MW-00800045.jpg
# ✅ 图片文件：PD16-MW-00800045.jpg → PD16-MW-00700045.jpg
#
# 【40/136】
# ✅ 标注文件：PD16-MW-00800046.txt → PD16-MW-00700046.txt（有效行：1）
# PD16-MW-00800046.jpg
# ✅ 图片文件：PD16-MW-00800046.jpg → PD16-MW-00700046.jpg
#
# 【41/136】
# ✅ 标注文件：PD16-MW-00800047.txt → PD16-MW-00700047.txt（有效行：1）
# PD16-MW-00800047.jpg
# ✅ 图片文件：PD16-MW-00800047.jpg → PD16-MW-00700047.jpg
#
# 【42/136】
# ✅ 标注文件：PD16-MW-00800048.txt → PD16-MW-00700048.txt（有效行：1）
# PD16-MW-00800048.jpg
# ✅ 图片文件：PD16-MW-00800048.jpg → PD16-MW-00700048.jpg
#
# 【43/136】
# ✅ 标注文件：PD16-MW-00800049.txt → PD16-MW-00700049.txt（有效行：1）
# PD16-MW-00800049.jpg
# ✅ 图片文件：PD16-MW-00800049.jpg → PD16-MW-00700049.jpg
#
# 【44/136】
# ✅ 标注文件：PD16-MW-00800051.txt → PD16-MW-00700051.txt（有效行：1）
# PD16-MW-00800051.jpg
# ✅ 图片文件：PD16-MW-00800051.jpg → PD16-MW-00700051.jpg
#
# 【45/136】
# ✅ 标注文件：PD16-MW-00800052.txt → PD16-MW-00700052.txt（有效行：1）
# PD16-MW-00800052.jpg
# ✅ 图片文件：PD16-MW-00800052.jpg → PD16-MW-00700052.jpg
#
# 【46/136】
# ✅ 标注文件：PD16-MW-00800053.txt → PD16-MW-00700053.txt（有效行：1）
# PD16-MW-00800053.jpg
# ✅ 图片文件：PD16-MW-00800053.jpg → PD16-MW-00700053.jpg
#
# 【47/136】
# ✅ 标注文件：PD16-MW-00800054.txt → PD16-MW-00700054.txt（有效行：1）
# PD16-MW-00800054.jpg
# ✅ 图片文件：PD16-MW-00800054.jpg → PD16-MW-00700054.jpg
#
# 【48/136】
# ✅ 标注文件：PD16-MW-00800055.txt → PD16-MW-00700055.txt（有效行：2）
# PD16-MW-00800055.jpg
# ✅ 图片文件：PD16-MW-00800055.jpg → PD16-MW-00700055.jpg
#
# 【49/136】
# ✅ 标注文件：PD16-MW-00800056.txt → PD16-MW-00700056.txt（有效行：3）
# PD16-MW-00800056.jpg
# ✅ 图片文件：PD16-MW-00800056.jpg → PD16-MW-00700056.jpg
#
# 【50/136】
# ✅ 标注文件：PD16-MW-00800057.txt → PD16-MW-00700057.txt（有效行：1）
# PD16-MW-00800057.jpg
# ✅ 图片文件：PD16-MW-00800057.jpg → PD16-MW-00700057.jpg
#
# 【51/136】
# ✅ 标注文件：PD16-MW-00800058.txt → PD16-MW-00700058.txt（有效行：1）
# PD16-MW-00800058.jpg
# ✅ 图片文件：PD16-MW-00800058.jpg → PD16-MW-00700058.jpg
#
# 【52/136】
# ✅ 标注文件：PD16-MW-00800059.txt → PD16-MW-00700059.txt（有效行：1）
# PD16-MW-00800059.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800059.jpg，跳过
#
# 【53/136】
# ✅ 标注文件：PD16-MW-00800060.txt → PD16-MW-00700060.txt（有效行：3）
# PD16-MW-00800060.jpg
# ✅ 图片文件：PD16-MW-00800060.jpg → PD16-MW-00700060.jpg
#
# 【54/136】
# ✅ 标注文件：PD16-MW-00800061.txt → PD16-MW-00700061.txt（有效行：9）
# PD16-MW-00800061.jpg
# ✅ 图片文件：PD16-MW-00800061.jpg → PD16-MW-00700061.jpg
#
# 【55/136】
# ✅ 标注文件：PD16-MW-00800062.txt → PD16-MW-00700062.txt（有效行：1）
# PD16-MW-00800062.jpg
# ✅ 图片文件：PD16-MW-00800062.jpg → PD16-MW-00700062.jpg
#
# 【56/136】
# ✅ 标注文件：PD16-MW-00800063.txt → PD16-MW-00700063.txt（有效行：2）
# PD16-MW-00800063.jpg
# ✅ 图片文件：PD16-MW-00800063.jpg → PD16-MW-00700063.jpg
#
# 【57/136】
# ✅ 标注文件：PD16-MW-00800065.txt → PD16-MW-00700065.txt（有效行：2）
# PD16-MW-00800065.jpg
# ✅ 图片文件：PD16-MW-00800065.jpg → PD16-MW-00700065.jpg
#
# 【58/136】
# ✅ 标注文件：PD16-MW-00800066.txt → PD16-MW-00700066.txt（有效行：1）
# PD16-MW-00800066.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800066.jpg，跳过
#
# 【59/136】
# ✅ 标注文件：PD16-MW-00800067.txt → PD16-MW-00700067.txt（有效行：1）
# PD16-MW-00800067.jpg
# ✅ 图片文件：PD16-MW-00800067.jpg → PD16-MW-00700067.jpg
#
# 【60/136】
# ✅ 标注文件：PD16-MW-00800069.txt → PD16-MW-00700069.txt（有效行：2）
# PD16-MW-00800069.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800069.jpg，跳过
#
# 【61/136】
# ✅ 标注文件：PD16-MW-00800070.txt → PD16-MW-00700070.txt（有效行：1）
# PD16-MW-00800070.jpg
# ✅ 图片文件：PD16-MW-00800070.jpg → PD16-MW-00700070.jpg
#
# 【62/136】
# ✅ 标注文件：PD16-MW-00800071.txt → PD16-MW-00700071.txt（有效行：1）
# PD16-MW-00800071.jpg
# ✅ 图片文件：PD16-MW-00800071.jpg → PD16-MW-00700071.jpg
#
# 【63/136】
# ✅ 标注文件：PD16-MW-00800072.txt → PD16-MW-00700072.txt（有效行：1）
# PD16-MW-00800072.jpg
# ✅ 图片文件：PD16-MW-00800072.jpg → PD16-MW-00700072.jpg
#
# 【64/136】
# ✅ 标注文件：PD16-MW-00800073.txt → PD16-MW-00700073.txt（有效行：1）
# PD16-MW-00800073.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800073.jpg，跳过
#
# 【65/136】
# ✅ 标注文件：PD16-MW-00800074.txt → PD16-MW-00700074.txt（有效行：1）
# PD16-MW-00800074.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800074.jpg，跳过
#
# 【66/136】
# ✅ 标注文件：PD16-MW-00800075.txt → PD16-MW-00700075.txt（有效行：1）
# PD16-MW-00800075.jpg
# ✅ 图片文件：PD16-MW-00800075.jpg → PD16-MW-00700075.jpg
#
# 【67/136】
# ✅ 标注文件：PD16-MW-00800077.txt → PD16-MW-00700077.txt（有效行：1）
# PD16-MW-00800077.jpg
# ✅ 图片文件：PD16-MW-00800077.jpg → PD16-MW-00700077.jpg
#
# 【68/136】
# ✅ 标注文件：PD16-MW-00800078.txt → PD16-MW-00700078.txt（有效行：5）
# PD16-MW-00800078.jpg
# ✅ 图片文件：PD16-MW-00800078.jpg → PD16-MW-00700078.jpg
#
# 【69/136】
# ✅ 标注文件：PD16-MW-00800079.txt → PD16-MW-00700079.txt（有效行：3）
# PD16-MW-00800079.jpg
# ✅ 图片文件：PD16-MW-00800079.jpg → PD16-MW-00700079.jpg
#
# 【70/136】
# ✅ 标注文件：PD16-MW-00800080.txt → PD16-MW-00700080.txt（有效行：4）
# PD16-MW-00800080.jpg
# ✅ 图片文件：PD16-MW-00800080.jpg → PD16-MW-00700080.jpg
#
# 【71/136】
# ✅ 标注文件：PD16-MW-00800081.txt → PD16-MW-00700081.txt（有效行：1）
# PD16-MW-00800081.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800081.jpg，跳过
#
# 【72/136】
# ✅ 标注文件：PD16-MW-00800082.txt → PD16-MW-00700082.txt（有效行：2）
# PD16-MW-00800082.jpg
# ✅ 图片文件：PD16-MW-00800082.jpg → PD16-MW-00700082.jpg
#
# 【73/136】
# ✅ 标注文件：PD16-MW-00800083.txt → PD16-MW-00700083.txt（有效行：1）
# PD16-MW-00800083.jpg
# ✅ 图片文件：PD16-MW-00800083.jpg → PD16-MW-00700083.jpg
#
# 【74/136】
# ✅ 标注文件：PD16-MW-00800084.txt → PD16-MW-00700084.txt（有效行：1）
# PD16-MW-00800084.jpg
# ✅ 图片文件：PD16-MW-00800084.jpg → PD16-MW-00700084.jpg
#
# 【75/136】
# ✅ 标注文件：PD16-MW-00800085.txt → PD16-MW-00700085.txt（有效行：1）
# PD16-MW-00800085.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800085.jpg，跳过
#
# 【76/136】
# ✅ 标注文件：PD16-MW-00800086.txt → PD16-MW-00700086.txt（有效行：1）
# PD16-MW-00800086.jpg
# ✅ 图片文件：PD16-MW-00800086.jpg → PD16-MW-00700086.jpg
#
# 【77/136】
# ✅ 标注文件：PD16-MW-00800087.txt → PD16-MW-00700087.txt（有效行：3）
# PD16-MW-00800087.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800087.jpg，跳过
#
# 【78/136】
# ✅ 标注文件：PD16-MW-00800088.txt → PD16-MW-00700088.txt（有效行：1）
# PD16-MW-00800088.jpg
# ✅ 图片文件：PD16-MW-00800088.jpg → PD16-MW-00700088.jpg
#
# 【79/136】
# ✅ 标注文件：PD16-MW-00800089.txt → PD16-MW-00700089.txt（有效行：2）
# PD16-MW-00800089.jpg
# ✅ 图片文件：PD16-MW-00800089.jpg → PD16-MW-00700089.jpg
#
# 【80/136】
# ✅ 标注文件：PD16-MW-00800090.txt → PD16-MW-00700090.txt（有效行：1）
# PD16-MW-00800090.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800090.jpg，跳过
#
# 【81/136】
# ✅ 标注文件：PD16-MW-00800091.txt → PD16-MW-00700091.txt（有效行：2）
# PD16-MW-00800091.jpg
# ✅ 图片文件：PD16-MW-00800091.jpg → PD16-MW-00700091.jpg
#
# 【82/136】
# ✅ 标注文件：PD16-MW-00800092.txt → PD16-MW-00700092.txt（有效行：6）
# PD16-MW-00800092.jpg
# ✅ 图片文件：PD16-MW-00800092.jpg → PD16-MW-00700092.jpg
#
# 【83/136】
# ✅ 标注文件：PD16-MW-00800093.txt → PD16-MW-00700093.txt（有效行：1）
# PD16-MW-00800093.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800093.jpg，跳过
#
# 【84/136】
# ✅ 标注文件：PD16-MW-00800094.txt → PD16-MW-00700094.txt（有效行：1）
# PD16-MW-00800094.jpg
# ✅ 图片文件：PD16-MW-00800094.jpg → PD16-MW-00700094.jpg
#
# 【85/136】
# ✅ 标注文件：PD16-MW-00800096.txt → PD16-MW-00700096.txt（有效行：10）
# PD16-MW-00800096.jpg
# ✅ 图片文件：PD16-MW-00800096.jpg → PD16-MW-00700096.jpg
#
# 【86/136】
# ✅ 标注文件：PD16-MW-00800097.txt → PD16-MW-00700097.txt（有效行：2）
# PD16-MW-00800097.jpg
# ✅ 图片文件：PD16-MW-00800097.jpg → PD16-MW-00700097.jpg
#
# 【87/136】
# ✅ 标注文件：PD16-MW-00800098.txt → PD16-MW-00700098.txt（有效行：3）
# PD16-MW-00800098.jpg
# ✅ 图片文件：PD16-MW-00800098.jpg → PD16-MW-00700098.jpg
#
# 【88/136】
# ✅ 标注文件：PD16-MW-00800099.txt → PD16-MW-00700099.txt（有效行：3）
# PD16-MW-00800099.jpg
# ✅ 图片文件：PD16-MW-00800099.jpg → PD16-MW-00700099.jpg
#
# 【89/136】
# ✅ 标注文件：PD16-MW-00800100.txt → PD16-MW-00700100.txt（有效行：1）
# PD16-MW-00800100.jpg
# ✅ 图片文件：PD16-MW-00800100.jpg → PD16-MW-00700100.jpg
#
# 【90/136】
# ✅ 标注文件：PD16-MW-00800101.txt → PD16-MW-00700101.txt（有效行：1）
# PD16-MW-00800101.jpg
# ✅ 图片文件：PD16-MW-00800101.jpg → PD16-MW-00700101.jpg
#
# 【91/136】
# ✅ 标注文件：PD16-MW-00800102.txt → PD16-MW-00700102.txt（有效行：1）
# PD16-MW-00800102.jpg
# ✅ 图片文件：PD16-MW-00800102.jpg → PD16-MW-00700102.jpg
#
# 【92/136】
# ✅ 标注文件：PD16-MW-00800103.txt → PD16-MW-00700103.txt（有效行：1）
# PD16-MW-00800103.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800103.jpg，跳过
#
# 【93/136】
# ✅ 标注文件：PD16-MW-00800104.txt → PD16-MW-00700104.txt（有效行：1）
# PD16-MW-00800104.jpg
# ✅ 图片文件：PD16-MW-00800104.jpg → PD16-MW-00700104.jpg
#
# 【94/136】
# ✅ 标注文件：PD16-MW-00800105.txt → PD16-MW-00700105.txt（有效行：1）
# PD16-MW-00800105.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800105.jpg，跳过
#
# 【95/136】
# ✅ 标注文件：PD16-MW-00800106.txt → PD16-MW-00700106.txt（有效行：1）
# PD16-MW-00800106.jpg
# ✅ 图片文件：PD16-MW-00800106.jpg → PD16-MW-00700106.jpg
#
# 【96/136】
# ✅ 标注文件：PD16-MW-00800108.txt → PD16-MW-00700108.txt（有效行：1）
# PD16-MW-00800108.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800108.jpg，跳过
#
# 【97/136】
# ✅ 标注文件：PD16-MW-00800109.txt → PD16-MW-00700109.txt（有效行：1）
# PD16-MW-00800109.jpg
# ✅ 图片文件：PD16-MW-00800109.jpg → PD16-MW-00700109.jpg
#
# 【98/136】
# ✅ 标注文件：PD16-MW-00800110.txt → PD16-MW-00700110.txt（有效行：2）
# PD16-MW-00800110.jpg
# ✅ 图片文件：PD16-MW-00800110.jpg → PD16-MW-00700110.jpg
#
# 【99/136】
# ✅ 标注文件：PD16-MW-00800112.txt → PD16-MW-00700112.txt（有效行：3）
# PD16-MW-00800112.jpg
# ✅ 图片文件：PD16-MW-00800112.jpg → PD16-MW-00700112.jpg
#
# 【100/136】
# ✅ 标注文件：PD16-MW-00800114.txt → PD16-MW-00700114.txt（有效行：1）
# PD16-MW-00800114.jpg
# ✅ 图片文件：PD16-MW-00800114.jpg → PD16-MW-00700114.jpg
#
# 【101/136】
# ✅ 标注文件：PD16-MW-00800115.txt → PD16-MW-00700115.txt（有效行：1）
# PD16-MW-00800115.jpg
# ✅ 图片文件：PD16-MW-00800115.jpg → PD16-MW-00700115.jpg
#
# 【102/136】
# ✅ 标注文件：PD16-MW-00800116.txt → PD16-MW-00700116.txt（有效行：1）
# PD16-MW-00800116.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800116.jpg，跳过
#
# 【103/136】
# ✅ 标注文件：PD16-MW-00800117.txt → PD16-MW-00700117.txt（有效行：3）
# PD16-MW-00800117.jpg
# ✅ 图片文件：PD16-MW-00800117.jpg → PD16-MW-00700117.jpg
#
# 【104/136】
# ✅ 标注文件：PD16-MW-00800118.txt → PD16-MW-00700118.txt（有效行：2）
# PD16-MW-00800118.jpg
# ✅ 图片文件：PD16-MW-00800118.jpg → PD16-MW-00700118.jpg
#
# 【105/136】
# ✅ 标注文件：PD16-MW-00800119.txt → PD16-MW-00700119.txt（有效行：8）
# PD16-MW-00800119.jpg
# ✅ 图片文件：PD16-MW-00800119.jpg → PD16-MW-00700119.jpg
#
# 【106/136】
# ✅ 标注文件：PD16-MW-00800120.txt → PD16-MW-00700120.txt（有效行：4）
# PD16-MW-00800120.jpg
# ✅ 图片文件：PD16-MW-00800120.jpg → PD16-MW-00700120.jpg
#
# 【107/136】
# ✅ 标注文件：PD16-MW-00800121.txt → PD16-MW-00700121.txt（有效行：4）
# PD16-MW-00800121.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800121.jpg，跳过
#
# 【108/136】
# ✅ 标注文件：PD16-MW-00800122.txt → PD16-MW-00700122.txt（有效行：1）
# PD16-MW-00800122.jpg
# ✅ 图片文件：PD16-MW-00800122.jpg → PD16-MW-00700122.jpg
#
# 【109/136】
# ✅ 标注文件：PD16-MW-00800123.txt → PD16-MW-00700123.txt（有效行：2）
# PD16-MW-00800123.jpg
# ✅ 图片文件：PD16-MW-00800123.jpg → PD16-MW-00700123.jpg
#
# 【110/136】
# ✅ 标注文件：PD16-MW-00800124.txt → PD16-MW-00700124.txt（有效行：1）
# PD16-MW-00800124.jpg
# ✅ 图片文件：PD16-MW-00800124.jpg → PD16-MW-00700124.jpg
#
# 【111/136】
# ✅ 标注文件：PD16-MW-00800126.txt → PD16-MW-00700126.txt（有效行：2）
# PD16-MW-00800126.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800126.jpg，跳过
#
# 【112/136】
# ✅ 标注文件：PD16-MW-00800127.txt → PD16-MW-00700127.txt（有效行：1）
# PD16-MW-00800127.jpg
# ✅ 图片文件：PD16-MW-00800127.jpg → PD16-MW-00700127.jpg
#
# 【113/136】
# ✅ 标注文件：PD16-MW-00800128.txt → PD16-MW-00700128.txt（有效行：2）
# PD16-MW-00800128.jpg
# ✅ 图片文件：PD16-MW-00800128.jpg → PD16-MW-00700128.jpg
#
# 【114/136】
# ✅ 标注文件：PD16-MW-00800129.txt → PD16-MW-00700129.txt（有效行：1）
# PD16-MW-00800129.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800129.jpg，跳过
#
# 【115/136】
# ✅ 标注文件：PD16-MW-00800130.txt → PD16-MW-00700130.txt（有效行：1）
# PD16-MW-00800130.jpg
# ✅ 图片文件：PD16-MW-00800130.jpg → PD16-MW-00700130.jpg
#
# 【116/136】
# ✅ 标注文件：PD16-MW-00800131.txt → PD16-MW-00700131.txt（有效行：1）
# PD16-MW-00800131.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800131.jpg，跳过
#
# 【117/136】
# ✅ 标注文件：PD16-MW-00800132.txt → PD16-MW-00700132.txt（有效行：3）
# PD16-MW-00800132.jpg
# ✅ 图片文件：PD16-MW-00800132.jpg → PD16-MW-00700132.jpg
#
# 【118/136】
# ✅ 标注文件：PD16-MW-00800133.txt → PD16-MW-00700133.txt（有效行：2）
# PD16-MW-00800133.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800133.jpg，跳过
#
# 【119/136】
# ✅ 标注文件：PD16-MW-00800134.txt → PD16-MW-00700134.txt（有效行：3）
# PD16-MW-00800134.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800134.jpg，跳过
#
# 【120/136】
# ✅ 标注文件：PD16-MW-00800135.txt → PD16-MW-00700135.txt（有效行：1）
# PD16-MW-00800135.jpg
# ✅ 图片文件：PD16-MW-00800135.jpg → PD16-MW-00700135.jpg
#
# 【121/136】
# ✅ 标注文件：PD16-MW-00800136.txt → PD16-MW-00700136.txt（有效行：1）
# PD16-MW-00800136.jpg
# ✅ 图片文件：PD16-MW-00800136.jpg → PD16-MW-00700136.jpg
#
# 【122/136】
# ✅ 标注文件：PD16-MW-00800137.txt → PD16-MW-00700137.txt（有效行：1）
# PD16-MW-00800137.jpg
# ✅ 图片文件：PD16-MW-00800137.jpg → PD16-MW-00700137.jpg
#
# 【123/136】
# ✅ 标注文件：PD16-MW-00800138.txt → PD16-MW-00700138.txt（有效行：1）
# PD16-MW-00800138.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800138.jpg，跳过
#
# 【124/136】
# ✅ 标注文件：PD16-MW-00800139.txt → PD16-MW-00700139.txt（有效行：1）
# PD16-MW-00800139.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800139.jpg，跳过
#
# 【125/136】
# ✅ 标注文件：PD16-MW-00800140.txt → PD16-MW-00700140.txt（有效行：2）
# PD16-MW-00800140.jpg
# ✅ 图片文件：PD16-MW-00800140.jpg → PD16-MW-00700140.jpg
#
# 【126/136】
# ✅ 标注文件：PD16-MW-00800143.txt → PD16-MW-00700143.txt（有效行：2）
# PD16-MW-00800143.jpg
# ✅ 图片文件：PD16-MW-00800143.jpg → PD16-MW-00700143.jpg
#
# 【127/136】
# ✅ 标注文件：PD16-MW-00800144.txt → PD16-MW-00700144.txt（有效行：1）
# PD16-MW-00800144.jpg
# ✅ 图片文件：PD16-MW-00800144.jpg → PD16-MW-00700144.jpg
#
# 【128/136】
# ✅ 标注文件：PD16-MW-00800145.txt → PD16-MW-00700145.txt（有效行：1）
# PD16-MW-00800145.jpg
# ✅ 图片文件：PD16-MW-00800145.jpg → PD16-MW-00700145.jpg
#
# 【129/136】
# ✅ 标注文件：PD16-MW-00800146.txt → PD16-MW-00700146.txt（有效行：3）
# PD16-MW-00800146.jpg
# ✅ 图片文件：PD16-MW-00800146.jpg → PD16-MW-00700146.jpg
#
# 【130/136】
# ✅ 标注文件：PD16-MW-00800147.txt → PD16-MW-00700147.txt（有效行：1）
# PD16-MW-00800147.jpg
# ✅ 图片文件：PD16-MW-00800147.jpg → PD16-MW-00700147.jpg
#
# 【131/136】
# ✅ 标注文件：PD16-MW-00800148.txt → PD16-MW-00700148.txt（有效行：1）
# PD16-MW-00800148.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800148.jpg，跳过
#
# 【132/136】
# ✅ 标注文件：PD16-MW-00800149.txt → PD16-MW-00700149.txt（有效行：1）
# PD16-MW-00800149.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800149.jpg，跳过
#
# 【133/136】
# ✅ 标注文件：PD16-MW-00800150.txt → PD16-MW-00700150.txt（有效行：3）
# PD16-MW-00800150.jpg
# ✅ 图片文件：PD16-MW-00800150.jpg → PD16-MW-00700150.jpg
#
# 【134/136】
# ✅ 标注文件：PD16-MW-00800151.txt → PD16-MW-00700151.txt（有效行：1）
# PD16-MW-00800151.jpg
# ✅ 图片文件：PD16-MW-00800151.jpg → PD16-MW-00700151.jpg
#
# 【135/136】
# ✅ 标注文件：PD16-MW-00800152.txt → PD16-MW-00700152.txt（有效行：2）
# PD16-MW-00800152.jpg
# ⚠️  图片文件不存在：D:\25.10.29backup\25.7.24\pest_text\api\data\images\08_wheat_midge\PD16-MW-00800152.jpg，跳过
#
# 【136/136】
# ✅ 标注文件：PD16-MW-00800153.txt → PD16-MW-00700153.txt（有效行：2）
# PD16-MW-00800153.jpg
# ✅ 图片文件：PD16-MW-00800153.jpg → PD16-MW-00700153.jpg
#
# 标注+图片处理统计：成功136个，失败0个
#
# ==================================================
# 开始处理描述文件...
# ==================================================
#
# 【中文描述文件】
# 处理目录：D:\25.10.29backup\25.7.24\pest_text\api\data\caption\08_wheat_midge
# 找到 104 个中文描述文件，开始处理...
# 📝 图片的文件名修改：PD16-MW-00800000.jpg → PD16-MW-00700000.jpg
# ✅ PD16-MW-00800000_caption.txt → PD16-MW-00700000_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800001.jpg → PD16-MW-00700001.jpg
# ✅ PD16-MW-00800001_caption.txt → PD16-MW-00700001_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800002.jpg → PD16-MW-00700002.jpg
# ✅ PD16-MW-00800002_caption.txt → PD16-MW-00700002_caption.txt
# ❌ 处理失败 PD16-MW-00800005_caption.txt：JSON处理失败：JSON格式错误：Expecting value: line 1 column 1 (char 0)
# 📝 图片的文件名修改：PD16-MW-00800006.jpg → PD16-MW-00700006.jpg
# ✅ PD16-MW-00800006_caption.txt → PD16-MW-00700006_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800007.jpg → PD16-MW-00700007.jpg
# ✅ PD16-MW-00800007_caption.txt → PD16-MW-00700007_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800009.jpg → PD16-MW-00700009.jpg
# ✅ PD16-MW-00800009_caption.txt → PD16-MW-00700009_caption.txt
# ❌ 处理失败 PD16-MW-00800010_caption.txt：JSON处理失败：JSON格式错误：Unterminated string starting at: line 47 column 19 (char 5175)
# 📝 图片的文件名修改：PD16-MW-00800013.jpg → PD16-MW-00700013.jpg
# ✅ PD16-MW-00800013_caption.txt → PD16-MW-00700013_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800015.jpg → PD16-MW-00700015.jpg
# ✅ PD16-MW-00800015_caption.txt → PD16-MW-00700015_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800017.jpg → PD16-MW-00700017.jpg
# ✅ PD16-MW-00800017_caption.txt → PD16-MW-00700017_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800018.jpg → PD16-MW-00700018.jpg
# ✅ PD16-MW-00800018_caption.txt → PD16-MW-00700018_caption.txt
# ❌ 处理失败 PD16-MW-00800020_caption.txt：JSON处理失败：JSON格式错误：Expecting value: line 1 column 1 (char 0)
# 📝 图片的文件名修改：PD16-MW-00800021.jpg → PD16-MW-00700021.jpg
# ✅ PD16-MW-00800021_caption.txt → PD16-MW-00700021_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800022.jpg → PD16-MW-00700022.jpg
# ✅ PD16-MW-00800022_caption.txt → PD16-MW-00700022_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800024.jpg → PD16-MW-00700024.jpg
# ✅ PD16-MW-00800024_caption.txt → PD16-MW-00700024_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800025.jpg → PD16-MW-00700025.jpg
# ✅ PD16-MW-00800025_caption.txt → PD16-MW-00700025_caption.txt
# ❌ 处理失败 PD16-MW-00800027_caption.txt：JSON处理失败：JSON格式错误：Expecting value: line 1 column 1 (char 0)
# 📝 图片的文件名修改：PD16-MW-00800029.jpg → PD16-MW-00700029.jpg
# ✅ PD16-MW-00800029_caption.txt → PD16-MW-00700029_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800030.jpg → PD16-MW-00700030.jpg
# ✅ PD16-MW-00800030_caption.txt → PD16-MW-00700030_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800031.jpg → PD16-MW-00700031.jpg
# ✅ PD16-MW-00800031_caption.txt → PD16-MW-00700031_caption.txt
# ❌ 处理失败 PD16-MW-00800032_caption.txt：JSON处理失败：JSON格式错误：Expecting value: line 1 column 1 (char 0)
# 📝 图片的文件名修改：PD16-MW-00800033.jpg → PD16-MW-00700033.jpg
# ✅ PD16-MW-00800033_caption.txt → PD16-MW-00700033_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800034.jpg → PD16-MW-00700034.jpg
# ✅ PD16-MW-00800034_caption.txt → PD16-MW-00700034_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800035.jpg → PD16-MW-00700035.jpg
# ✅ PD16-MW-00800035_caption.txt → PD16-MW-00700035_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800038.jpg → PD16-MW-00700038.jpg
# ✅ PD16-MW-00800038_caption.txt → PD16-MW-00700038_caption.txt
# ❌ 处理失败 PD16-MW-00800039_caption.txt：JSON处理失败：JSON格式错误：Expecting value: line 1 column 1 (char 0)
# 📝 图片的文件名修改：PD16-MW-00800040.jpg → PD16-MW-00700040.jpg
# ✅ PD16-MW-00800040_caption.txt → PD16-MW-00700040_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800042.jpg → PD16-MW-00700042.jpg
# ✅ PD16-MW-00800042_caption.txt → PD16-MW-00700042_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800043.jpg → PD16-MW-00700043.jpg
# ✅ PD16-MW-00800043_caption.txt → PD16-MW-00700043_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800044.jpg → PD16-MW-00700044.jpg
# ✅ PD16-MW-00800044_caption.txt → PD16-MW-00700044_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800045.jpg → PD16-MW-00700045.jpg
# ✅ PD16-MW-00800045_caption.txt → PD16-MW-00700045_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800046.jpg → PD16-MW-00700046.jpg
# ✅ PD16-MW-00800046_caption.txt → PD16-MW-00700046_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800047.jpg → PD16-MW-00700047.jpg
# ✅ PD16-MW-00800047_caption.txt → PD16-MW-00700047_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800048.jpg → PD16-MW-00700048.jpg
# ✅ PD16-MW-00800048_caption.txt → PD16-MW-00700048_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800049.jpg → PD16-MW-00700049.jpg
# ✅ PD16-MW-00800049_caption.txt → PD16-MW-00700049_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800051.jpg → PD16-MW-00700051.jpg
# ✅ PD16-MW-00800051_caption.txt → PD16-MW-00700051_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800052.jpg → PD16-MW-00700052.jpg
# ✅ PD16-MW-00800052_caption.txt → PD16-MW-00700052_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800053.jpg → PD16-MW-00700053.jpg
# ✅ PD16-MW-00800053_caption.txt → PD16-MW-00700053_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800054.jpg → PD16-MW-00700054.jpg
# ✅ PD16-MW-00800054_caption.txt → PD16-MW-00700054_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800055.jpg → PD16-MW-00700055.jpg
# ✅ PD16-MW-00800055_caption.txt → PD16-MW-00700055_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800056.jpg → PD16-MW-00700056.jpg
# ✅ PD16-MW-00800056_caption.txt → PD16-MW-00700056_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800057.jpg → PD16-MW-00700057.jpg
# ✅ PD16-MW-00800057_caption.txt → PD16-MW-00700057_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800058.jpg → PD16-MW-00700058.jpg
# ✅ PD16-MW-00800058_caption.txt → PD16-MW-00700058_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800060.jpg → PD16-MW-00700060.jpg
# ✅ PD16-MW-00800060_caption.txt → PD16-MW-00700060_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800061.jpg → PD16-MW-00700061.jpg
# ✅ PD16-MW-00800061_caption.txt → PD16-MW-00700061_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800062.jpg → PD16-MW-00700062.jpg
# ✅ PD16-MW-00800062_caption.txt → PD16-MW-00700062_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800063.jpg → PD16-MW-00700063.jpg
# ✅ PD16-MW-00800063_caption.txt → PD16-MW-00700063_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800065.jpg → PD16-MW-00700065.jpg
# ✅ PD16-MW-00800065_caption.txt → PD16-MW-00700065_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800067.jpg → PD16-MW-00700067.jpg
# ✅ PD16-MW-00800067_caption.txt → PD16-MW-00700067_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800070.jpg → PD16-MW-00700070.jpg
# ✅ PD16-MW-00800070_caption.txt → PD16-MW-00700070_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800071.jpg → PD16-MW-00700071.jpg
# ✅ PD16-MW-00800071_caption.txt → PD16-MW-00700071_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800072.jpg → PD16-MW-00700072.jpg
# ✅ PD16-MW-00800072_caption.txt → PD16-MW-00700072_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800075.jpg → PD16-MW-00700075.jpg
# ✅ PD16-MW-00800075_caption.txt → PD16-MW-00700075_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800077.jpg → PD16-MW-00700077.jpg
# ✅ PD16-MW-00800077_caption.txt → PD16-MW-00700077_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800078.jpg → PD16-MW-00700078.jpg
# ✅ PD16-MW-00800078_caption.txt → PD16-MW-00700078_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800079.jpg → PD16-MW-00700079.jpg
# ✅ PD16-MW-00800079_caption.txt → PD16-MW-00700079_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800080.jpg → PD16-MW-00700080.jpg
# ✅ PD16-MW-00800080_caption.txt → PD16-MW-00700080_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800082.jpg → PD16-MW-00700082.jpg
# ✅ PD16-MW-00800082_caption.txt → PD16-MW-00700082_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800083.jpg → PD16-MW-00700083.jpg
# ✅ PD16-MW-00800083_caption.txt → PD16-MW-00700083_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800084.jpg → PD16-MW-00700084.jpg
# ✅ PD16-MW-00800084_caption.txt → PD16-MW-00700084_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800086.jpg → PD16-MW-00700086.jpg
# ✅ PD16-MW-00800086_caption.txt → PD16-MW-00700086_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800088.jpg → PD16-MW-00700088.jpg
# ✅ PD16-MW-00800088_caption.txt → PD16-MW-00700088_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800089.jpg → PD16-MW-00700089.jpg
# ✅ PD16-MW-00800089_caption.txt → PD16-MW-00700089_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800091.jpg → PD16-MW-00700091.jpg
# ✅ PD16-MW-00800091_caption.txt → PD16-MW-00700091_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800092.jpg → PD16-MW-00700092.jpg
# ✅ PD16-MW-00800092_caption.txt → PD16-MW-00700092_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800094.jpg → PD16-MW-00700094.jpg
# ✅ PD16-MW-00800094_caption.txt → PD16-MW-00700094_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800096.jpg → PD16-MW-00700096.jpg
# ✅ PD16-MW-00800096_caption.txt → PD16-MW-00700096_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800097.jpg → PD16-MW-00700097.jpg
# ✅ PD16-MW-00800097_caption.txt → PD16-MW-00700097_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800098.jpg → PD16-MW-00700098.jpg
# ✅ PD16-MW-00800098_caption.txt → PD16-MW-00700098_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800099.jpg → PD16-MW-00700099.jpg
# ✅ PD16-MW-00800099_caption.txt → PD16-MW-00700099_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800100.jpg → PD16-MW-00700100.jpg
# ✅ PD16-MW-00800100_caption.txt → PD16-MW-00700100_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800101.jpg → PD16-MW-00700101.jpg
# ✅ PD16-MW-00800101_caption.txt → PD16-MW-00700101_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800102.jpg → PD16-MW-00700102.jpg
# ✅ PD16-MW-00800102_caption.txt → PD16-MW-00700102_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800104.jpg → PD16-MW-00700104.jpg
# ✅ PD16-MW-00800104_caption.txt → PD16-MW-00700104_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800106.jpg → PD16-MW-00700106.jpg
# ✅ PD16-MW-00800106_caption.txt → PD16-MW-00700106_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800109.jpg → PD16-MW-00700109.jpg
# ✅ PD16-MW-00800109_caption.txt → PD16-MW-00700109_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800110.jpg → PD16-MW-00700110.jpg
# ✅ PD16-MW-00800110_caption.txt → PD16-MW-00700110_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800112.jpg → PD16-MW-00700112.jpg
# ✅ PD16-MW-00800112_caption.txt → PD16-MW-00700112_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800114.jpg → PD16-MW-00700114.jpg
# ✅ PD16-MW-00800114_caption.txt → PD16-MW-00700114_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800115.jpg → PD16-MW-00700115.jpg
# ✅ PD16-MW-00800115_caption.txt → PD16-MW-00700115_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800117.jpg → PD16-MW-00700117.jpg
# ✅ PD16-MW-00800117_caption.txt → PD16-MW-00700117_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800118.jpg → PD16-MW-00700118.jpg
# ✅ PD16-MW-00800118_caption.txt → PD16-MW-00700118_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800119.jpg → PD16-MW-00700119.jpg
# ✅ PD16-MW-00800119_caption.txt → PD16-MW-00700119_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800120.jpg → PD16-MW-00700120.jpg
# ✅ PD16-MW-00800120_caption.txt → PD16-MW-00700120_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800122.jpg → PD16-MW-00700122.jpg
# ✅ PD16-MW-00800122_caption.txt → PD16-MW-00700122_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800123.jpg → PD16-MW-00700123.jpg
# ✅ PD16-MW-00800123_caption.txt → PD16-MW-00700123_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800124.jpg → PD16-MW-00700124.jpg
# ✅ PD16-MW-00800124_caption.txt → PD16-MW-00700124_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800127.jpg → PD16-MW-00700127.jpg
# ✅ PD16-MW-00800127_caption.txt → PD16-MW-00700127_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800128.jpg → PD16-MW-00700128.jpg
# ✅ PD16-MW-00800128_caption.txt → PD16-MW-00700128_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800130.jpg → PD16-MW-00700130.jpg
# ✅ PD16-MW-00800130_caption.txt → PD16-MW-00700130_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800132.jpg → PD16-MW-00700132.jpg
# ✅ PD16-MW-00800132_caption.txt → PD16-MW-00700132_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800135.jpg → PD16-MW-00700135.jpg
# ✅ PD16-MW-00800135_caption.txt → PD16-MW-00700135_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800136.jpg → PD16-MW-00700136.jpg
# ✅ PD16-MW-00800136_caption.txt → PD16-MW-00700136_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800137.jpg → PD16-MW-00700137.jpg
# ✅ PD16-MW-00800137_caption.txt → PD16-MW-00700137_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800140.jpg → PD16-MW-00700140.jpg
# ✅ PD16-MW-00800140_caption.txt → PD16-MW-00700140_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800143.jpg → PD16-MW-00700143.jpg
# ✅ PD16-MW-00800143_caption.txt → PD16-MW-00700143_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800144.jpg → PD16-MW-00700144.jpg
# ✅ PD16-MW-00800144_caption.txt → PD16-MW-00700144_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800145.jpg → PD16-MW-00700145.jpg
# ✅ PD16-MW-00800145_caption.txt → PD16-MW-00700145_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800146.jpg → PD16-MW-00700146.jpg
# ✅ PD16-MW-00800146_caption.txt → PD16-MW-00700146_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800147.jpg → PD16-MW-00700147.jpg
# ✅ PD16-MW-00800147_caption.txt → PD16-MW-00700147_caption.txt
# 📝 图片的文件名修改：PD16-MW-00800150.jpg → PD16-MW-00700150.jpg
# ✅ PD16-MW-00800150_caption.txt → PD16-MW-00700150_caption.txt
# ❌ 处理失败 PD16-MW-00800151_caption.txt：JSON处理失败：JSON格式错误：Expecting value: line 1 column 1 (char 0)
# 📝 图片的文件名修改：PD16-MW-00800153.jpg → PD16-MW-00700153.jpg
# ✅ PD16-MW-00800153_caption.txt → PD16-MW-00700153_caption.txt
# 中文描述文件处理完成：成功97个，失败7个
#
# 【英文描述文件】
# 处理目录：D:\25.10.29backup\25.7.24\pest_text\api\data\caption_en\08_wheat_midge
# 找到 104 个英文描述文件，开始处理...
# 📝 Image filename修改：PD16-MW-00800000.jpg → PD16-MW-00700000.jpg
# ✅ PD16-MW-00800000_caption_en.txt → PD16-MW-00700000_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800001.jpg → PD16-MW-00700001.jpg
# ✅ PD16-MW-00800001_caption_en.txt → PD16-MW-00700001_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800002.jpg → PD16-MW-00700002.jpg
# ✅ PD16-MW-00800002_caption_en.txt → PD16-MW-00700002_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800005.jpg → PD16-MW-00700005.jpg
# ✅ PD16-MW-00800005_caption_en.txt → PD16-MW-00700005_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800006.jpg → PD16-MW-00700006.jpg
# ✅ PD16-MW-00800006_caption_en.txt → PD16-MW-00700006_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800007.jpg → PD16-MW-00700007.jpg
# ✅ PD16-MW-00800007_caption_en.txt → PD16-MW-00700007_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800009.jpg → PD16-MW-00700009.jpg
# ✅ PD16-MW-00800009_caption_en.txt → PD16-MW-00700009_caption_en.txt
# ❌ 处理失败 PD16-MW-00800010_caption_en.txt：JSON处理失败：JSON格式错误：Unterminated string starting at: line 38 column 43 (char 11749)
# 📝 Image filename修改：PD16-MW-00800013.jpg → PD16-MW-00700013.jpg
# ✅ PD16-MW-00800013_caption_en.txt → PD16-MW-00700013_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800015.jpg → PD16-MW-00700015.jpg
# ✅ PD16-MW-00800015_caption_en.txt → PD16-MW-00700015_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800017.jpg → PD16-MW-00700017.jpg
# ✅ PD16-MW-00800017_caption_en.txt → PD16-MW-00700017_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800018.jpg → PD16-MW-00700018.jpg
# ✅ PD16-MW-00800018_caption_en.txt → PD16-MW-00700018_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800020.jpg → PD16-MW-00700020.jpg
# ✅ PD16-MW-00800020_caption_en.txt → PD16-MW-00700020_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800021.jpg → PD16-MW-00700021.jpg
# ✅ PD16-MW-00800021_caption_en.txt → PD16-MW-00700021_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800022.jpg → PD16-MW-00700022.jpg
# ✅ PD16-MW-00800022_caption_en.txt → PD16-MW-00700022_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800024.jpg → PD16-MW-00700024.jpg
# ✅ PD16-MW-00800024_caption_en.txt → PD16-MW-00700024_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800025.jpg → PD16-MW-00700025.jpg
# ✅ PD16-MW-00800025_caption_en.txt → PD16-MW-00700025_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800027.jpg → PD16-MW-00700027.jpg
# ✅ PD16-MW-00800027_caption_en.txt → PD16-MW-00700027_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800029.jpg → PD16-MW-00700029.jpg
# ✅ PD16-MW-00800029_caption_en.txt → PD16-MW-00700029_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800030.jpg → PD16-MW-00700030.jpg
# ✅ PD16-MW-00800030_caption_en.txt → PD16-MW-00700030_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800031.jpg → PD16-MW-00700031.jpg
# ✅ PD16-MW-00800031_caption_en.txt → PD16-MW-00700031_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800032.jpg → PD16-MW-00700032.jpg
# ✅ PD16-MW-00800032_caption_en.txt → PD16-MW-00700032_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800033.jpg → PD16-MW-00700033.jpg
# ✅ PD16-MW-00800033_caption_en.txt → PD16-MW-00700033_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800034.jpg → PD16-MW-00700034.jpg
# ✅ PD16-MW-00800034_caption_en.txt → PD16-MW-00700034_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800035.jpg → PD16-MW-00700035.jpg
# ✅ PD16-MW-00800035_caption_en.txt → PD16-MW-00700035_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800038.jpg → PD16-MW-00700038.jpg
# ✅ PD16-MW-00800038_caption_en.txt → PD16-MW-00700038_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800039.jpg → PD16-MW-00700039.jpg
# ✅ PD16-MW-00800039_caption_en.txt → PD16-MW-00700039_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800040.jpg → PD16-MW-00700040.jpg
# ✅ PD16-MW-00800040_caption_en.txt → PD16-MW-00700040_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800042.jpg → PD16-MW-00700042.jpg
# ✅ PD16-MW-00800042_caption_en.txt → PD16-MW-00700042_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800043.jpg → PD16-MW-00700043.jpg
# ✅ PD16-MW-00800043_caption_en.txt → PD16-MW-00700043_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800044.jpg → PD16-MW-00700044.jpg
# ✅ PD16-MW-00800044_caption_en.txt → PD16-MW-00700044_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800045.jpg → PD16-MW-00700045.jpg
# ✅ PD16-MW-00800045_caption_en.txt → PD16-MW-00700045_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800046.jpg → PD16-MW-00700046.jpg
# ✅ PD16-MW-00800046_caption_en.txt → PD16-MW-00700046_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800047.jpg → PD16-MW-00700047.jpg
# ✅ PD16-MW-00800047_caption_en.txt → PD16-MW-00700047_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800048.jpg → PD16-MW-00700048.jpg
# ✅ PD16-MW-00800048_caption_en.txt → PD16-MW-00700048_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800049.jpg → PD16-MW-00700049.jpg
# ✅ PD16-MW-00800049_caption_en.txt → PD16-MW-00700049_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800051.jpg → PD16-MW-00700051.jpg
# ✅ PD16-MW-00800051_caption_en.txt → PD16-MW-00700051_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800052.jpg → PD16-MW-00700052.jpg
# ✅ PD16-MW-00800052_caption_en.txt → PD16-MW-00700052_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800053.jpg → PD16-MW-00700053.jpg
# ✅ PD16-MW-00800053_caption_en.txt → PD16-MW-00700053_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800054.jpg → PD16-MW-00700054.jpg
# ✅ PD16-MW-00800054_caption_en.txt → PD16-MW-00700054_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800055.jpg → PD16-MW-00700055.jpg
# ✅ PD16-MW-00800055_caption_en.txt → PD16-MW-00700055_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800056.jpg → PD16-MW-00700056.jpg
# ✅ PD16-MW-00800056_caption_en.txt → PD16-MW-00700056_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800057.jpg → PD16-MW-00700057.jpg
# ✅ PD16-MW-00800057_caption_en.txt → PD16-MW-00700057_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800058.jpg → PD16-MW-00700058.jpg
# ✅ PD16-MW-00800058_caption_en.txt → PD16-MW-00700058_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800060.jpg → PD16-MW-00700060.jpg
# ✅ PD16-MW-00800060_caption_en.txt → PD16-MW-00700060_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800061.jpg → PD16-MW-00700061.jpg
# ✅ PD16-MW-00800061_caption_en.txt → PD16-MW-00700061_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800062.jpg → PD16-MW-00700062.jpg
# ✅ PD16-MW-00800062_caption_en.txt → PD16-MW-00700062_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800063.jpg → PD16-MW-00700063.jpg
# ✅ PD16-MW-00800063_caption_en.txt → PD16-MW-00700063_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800065.jpg → PD16-MW-00700065.jpg
# ✅ PD16-MW-00800065_caption_en.txt → PD16-MW-00700065_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800067.jpg → PD16-MW-00700067.jpg
# ✅ PD16-MW-00800067_caption_en.txt → PD16-MW-00700067_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800070.jpg → PD16-MW-00700070.jpg
# ✅ PD16-MW-00800070_caption_en.txt → PD16-MW-00700070_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800071.jpg → PD16-MW-00700071.jpg
# ✅ PD16-MW-00800071_caption_en.txt → PD16-MW-00700071_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800072.jpg → PD16-MW-00700072.jpg
# ✅ PD16-MW-00800072_caption_en.txt → PD16-MW-00700072_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800075.jpg → PD16-MW-00700075.jpg
# ✅ PD16-MW-00800075_caption_en.txt → PD16-MW-00700075_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800077.jpg → PD16-MW-00700077.jpg
# ✅ PD16-MW-00800077_caption_en.txt → PD16-MW-00700077_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800078.jpg → PD16-MW-00700078.jpg
# ✅ PD16-MW-00800078_caption_en.txt → PD16-MW-00700078_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800079.jpg → PD16-MW-00700079.jpg
# ✅ PD16-MW-00800079_caption_en.txt → PD16-MW-00700079_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800080.jpg → PD16-MW-00700080.jpg
# ✅ PD16-MW-00800080_caption_en.txt → PD16-MW-00700080_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800082.jpg → PD16-MW-00700082.jpg
# ✅ PD16-MW-00800082_caption_en.txt → PD16-MW-00700082_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800083.jpg → PD16-MW-00700083.jpg
# ✅ PD16-MW-00800083_caption_en.txt → PD16-MW-00700083_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800084.jpg → PD16-MW-00700084.jpg
# ✅ PD16-MW-00800084_caption_en.txt → PD16-MW-00700084_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800086.jpg → PD16-MW-00700086.jpg
# ✅ PD16-MW-00800086_caption_en.txt → PD16-MW-00700086_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800088.jpg → PD16-MW-00700088.jpg
# ✅ PD16-MW-00800088_caption_en.txt → PD16-MW-00700088_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800089.jpg → PD16-MW-00700089.jpg
# ✅ PD16-MW-00800089_caption_en.txt → PD16-MW-00700089_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800091.jpg → PD16-MW-00700091.jpg
# ✅ PD16-MW-00800091_caption_en.txt → PD16-MW-00700091_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800092.jpg → PD16-MW-00700092.jpg
# ✅ PD16-MW-00800092_caption_en.txt → PD16-MW-00700092_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800094.jpg → PD16-MW-00700094.jpg
# ✅ PD16-MW-00800094_caption_en.txt → PD16-MW-00700094_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800096.jpg → PD16-MW-00700096.jpg
# ✅ PD16-MW-00800096_caption_en.txt → PD16-MW-00700096_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800097.jpg → PD16-MW-00700097.jpg
# ✅ PD16-MW-00800097_caption_en.txt → PD16-MW-00700097_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800098.jpg → PD16-MW-00700098.jpg
# ✅ PD16-MW-00800098_caption_en.txt → PD16-MW-00700098_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800099.jpg → PD16-MW-00700099.jpg
# ✅ PD16-MW-00800099_caption_en.txt → PD16-MW-00700099_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800100.jpg → PD16-MW-00700100.jpg
# ✅ PD16-MW-00800100_caption_en.txt → PD16-MW-00700100_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800101.jpg → PD16-MW-00700101.jpg
# ✅ PD16-MW-00800101_caption_en.txt → PD16-MW-00700101_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800102.jpg → PD16-MW-00700102.jpg
# ✅ PD16-MW-00800102_caption_en.txt → PD16-MW-00700102_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800104.jpg → PD16-MW-00700104.jpg
# ✅ PD16-MW-00800104_caption_en.txt → PD16-MW-00700104_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800106.jpg → PD16-MW-00700106.jpg
# ✅ PD16-MW-00800106_caption_en.txt → PD16-MW-00700106_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800109.jpg → PD16-MW-00700109.jpg
# ✅ PD16-MW-00800109_caption_en.txt → PD16-MW-00700109_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800110.jpg → PD16-MW-00700110.jpg
# ✅ PD16-MW-00800110_caption_en.txt → PD16-MW-00700110_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800112.jpg → PD16-MW-00700112.jpg
# ✅ PD16-MW-00800112_caption_en.txt → PD16-MW-00700112_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800114.jpg → PD16-MW-00700114.jpg
# ✅ PD16-MW-00800114_caption_en.txt → PD16-MW-00700114_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800115.jpg → PD16-MW-00700115.jpg
# ✅ PD16-MW-00800115_caption_en.txt → PD16-MW-00700115_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800117.jpg → PD16-MW-00700117.jpg
# ✅ PD16-MW-00800117_caption_en.txt → PD16-MW-00700117_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800118.jpg → PD16-MW-00700118.jpg
# ✅ PD16-MW-00800118_caption_en.txt → PD16-MW-00700118_caption_en.txt
# ❌ 处理失败 PD16-MW-00800119_caption_en.txt：JSON处理失败：JSON格式错误：Unterminated string starting at: line 38 column 43 (char 11469)
# 📝 Image filename修改：PD16-MW-00800120.jpg → PD16-MW-00700120.jpg
# ✅ PD16-MW-00800120_caption_en.txt → PD16-MW-00700120_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800122.jpg → PD16-MW-00700122.jpg
# ✅ PD16-MW-00800122_caption_en.txt → PD16-MW-00700122_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800123.jpg → PD16-MW-00700123.jpg
# ✅ PD16-MW-00800123_caption_en.txt → PD16-MW-00700123_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800124.jpg → PD16-MW-00700124.jpg
# ✅ PD16-MW-00800124_caption_en.txt → PD16-MW-00700124_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800127.jpg → PD16-MW-00700127.jpg
# ✅ PD16-MW-00800127_caption_en.txt → PD16-MW-00700127_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800128.jpg → PD16-MW-00700128.jpg
# ✅ PD16-MW-00800128_caption_en.txt → PD16-MW-00700128_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800130.jpg → PD16-MW-00700130.jpg
# ✅ PD16-MW-00800130_caption_en.txt → PD16-MW-00700130_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800132.jpg → PD16-MW-00700132.jpg
# ✅ PD16-MW-00800132_caption_en.txt → PD16-MW-00700132_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800135.jpg → PD16-MW-00700135.jpg
# ✅ PD16-MW-00800135_caption_en.txt → PD16-MW-00700135_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800136.jpg → PD16-MW-00700136.jpg
# ✅ PD16-MW-00800136_caption_en.txt → PD16-MW-00700136_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800137.jpg → PD16-MW-00700137.jpg
# ✅ PD16-MW-00800137_caption_en.txt → PD16-MW-00700137_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800140.jpg → PD16-MW-00700140.jpg
# ✅ PD16-MW-00800140_caption_en.txt → PD16-MW-00700140_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800143.jpg → PD16-MW-00700143.jpg
# ✅ PD16-MW-00800143_caption_en.txt → PD16-MW-00700143_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800144.jpg → PD16-MW-00700144.jpg
# ✅ PD16-MW-00800144_caption_en.txt → PD16-MW-00700144_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800145.jpg → PD16-MW-00700145.jpg
# ✅ PD16-MW-00800145_caption_en.txt → PD16-MW-00700145_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800146.jpg → PD16-MW-00700146.jpg
# ✅ PD16-MW-00800146_caption_en.txt → PD16-MW-00700146_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800147.jpg → PD16-MW-00700147.jpg
# ✅ PD16-MW-00800147_caption_en.txt → PD16-MW-00700147_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800150.jpg → PD16-MW-00700150.jpg
# ✅ PD16-MW-00800150_caption_en.txt → PD16-MW-00700150_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800151.jpg → PD16-MW-00700151.jpg
# ✅ PD16-MW-00800151_caption_en.txt → PD16-MW-00700151_caption_en.txt
# 📝 Image filename修改：PD16-MW-00800153.jpg → PD16-MW-00700153.jpg
# ✅ PD16-MW-00800153_caption_en.txt → PD16-MW-00700153_caption_en.txt
# 英文描述文件处理完成：成功102个，失败2个
#
# ============================================================
# 全部处理完成！
# ============================================================
# 标注+图片文件：成功136个，失败0个
# 描述文件：成功199个，失败9个
#
# 处理后的文件保存位置：
# - 标注文件：D:\25.10.29backup\25.7.24\pest_text\api\data_processed\bbox_processed\07_wheat_midge
# - 图片文件：D:\25.10.29backup\25.7.24\pest_text\api\data_processed\images_processed\07_wheat_midge
# - 中文描述：D:\25.10.29backup\25.7.24\pest_text\api\data_processed\caption_processed\07_wheat_midge
# - 英文描述：D:\25.10.29backup\25.7.24\pest_text\api\data_processed\caption_en_processed\07_wheat_midge
# ============================================================
